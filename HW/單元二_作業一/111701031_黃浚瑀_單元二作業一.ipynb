# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/8月份交通事故資料.csv')

# %%
#第一題:
print ('前五行資料:\n', df.head(5))
print ('='*90)
print ('\n後五行資料:\n', df.tail(5))
print ('='*90)
print ('\n數據基本資訊:\n')
df.info()
print (f'列數:{df.shape[0]}')
# Out:
# 前五行資料:
#     序號  縣市別代碼        機關代碼            市話            傳真     年  月  日  時   分  ...  \
# 0   1  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  0  14  ...
# 1   2  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  4   5  ...
# 2   3  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  4   9  ...
# 3   4  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  6  25  ...
# 4   5  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  6  30  ...
#
#   車輛撞擊部位其他 肇事因素個別  肇事因素主要  肇事逃逸    職業  旅次目的   車種      GPS座標X     GPS座標Y  事故類別
# 0      NaN   15.0    15.0   1.0  12.0   4.0  C03  120.732086  24.150122     2
# 1      NaN    7.0     7.0   1.0  12.0   4.0  B12  120.647788  24.171075     3
# 2      NaN   59.0    59.0   1.0  12.0   4.0  B03  120.751381  24.260691     2
# 3      NaN   40.0    40.0   1.0  13.0   4.0  B12  120.657855  24.129151     2
# 4      NaN   35.0     NaN   1.0   6.0   4.0  B03  120.597591  24.249998     3
#
# [5 rows x 55 columns]
# ...
#
# ...

# %%
#第二題:
df.describe()
# Out:
#                  序號    縣市別代碼        年        月             日             時  \
# count  12141.000000  12141.0  12141.0  12141.0  12141.000000  12141.000000
# mean    6071.000000  66000.0   2023.0      8.0     16.013096     13.375587
# std     3504.949144      0.0      0.0      0.0      8.917011      4.838949
# min        1.000000  66000.0   2023.0      8.0      1.000000      0.000000
# 25%     3036.000000  66000.0   2023.0      8.0      8.000000      9.000000
# 50%     6071.000000  66000.0   2023.0      8.0     16.000000     14.000000
# 75%     9106.000000  66000.0   2023.0      8.0     24.000000     17.000000
# max    12141.000000  66000.0   2023.0      8.0     31.000000     23.000000
#
#                   分          死亡數量          受傷數量     2-30  ...     車輛撞擊部位最初  \
# count  12141.000000  12141.000000  12141.000000  12141.0  ...  6121.000000
# mean      29.363479      0.000577      0.643192      0.0  ...     9.191799
# ...

# %%
#第三題
mask1 = (df['區'] == '西屯區')
mask2 = (df['事故類型及型態'] == 17)
print (df[mask1 & mask2].head(5))
# Out:
#       序號  縣市別代碼        機關代碼            市話            傳真     年  月  日   時   分  \
# 46    47  66000  387130000C  (04)23274275  (04)23288582  2023  8  1   8   0
# 302  303  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  17  50
# 321  322  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  18  30
# 388  389  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  22  50
# 392  393  66000  387130000C  (04)23274275  (04)23288582  2023  8  1  23  36
#
#      ... 車輛撞擊部位其他 肇事因素個別  肇事因素主要  肇事逃逸    職業  旅次目的   車種      GPS座標X  \
# 46   ...      NaN   20.0    20.0   1.0  13.0   4.0  B03  120.615268
# 302  ...      NaN   14.0    14.0   1.0  13.0   4.0  B03  120.624398
# 321  ...      NaN   84.0    84.0   1.0  13.0   4.0  B02  120.665366
# 388  ...      NaN   84.0    84.0   1.0  13.0   4.0  C03  120.639433
# 392  ...      NaN   85.0    85.0   1.0  13.0   4.0  C03  120.613401
#
#         GPS座標Y  事故類別
# 46   24.182938     2
# 302  24.175478     2
# 321  24.166799     2
# ...

# %%
#第四題
print (df.iloc[1:5, 2:6])
# Out:
#          機關代碼            市話            傳真     年
# 1  387130000C  (04)23274275  (04)23288582  2023
# 2  387130000C  (04)23274275  (04)23288582  2023
# 3  387130000C  (04)23274275  (04)23288582  2023
# 4  387130000C  (04)23274275  (04)23288582  2023
